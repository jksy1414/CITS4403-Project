# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), ".."))  # make 'src' and 'utils' importable
from src.model import Params
from src.simulate import simulate
from utils.plotting import plot_curves

p = Params(topology="BA", n=2000, T=60)
out = simulate(p)
plot_curves(out, "BA")
